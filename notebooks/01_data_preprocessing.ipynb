# %% [markdown]
# # Data Acquisition, Preprocessing, Tokenization & Vectorization for Symbolic-Music Composer Classification

# %% [markdown]
# ## 1. Environment Setup

# %%
# ---------------------------------------------------------------------------
# 1.1 Package installation (Kaggle kernels: run once per session)
# ---------------------------------------------------------------------------
import sys, subprocess

def pip_install(packages):
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", *packages])

pip_install(["music21", "pretty_midi", "gensim"])

# ---------------------------------------------------------------------------
# 1.2 Imports
# ---------------------------------------------------------------------------
import os
import re
import glob
import time
import pickle
import random
import warnings
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import music21
import pretty_midi

import nltk
from nltk.corpus import stopwords as nltk_stopwords
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

from gensim.models import Word2Vec

warnings.filterwarnings("ignore")

# NLTK resources needed for the *literal* text-preprocessing demonstrations
# (Section 3.2 metadata tokenization, Section 5.1 stopword reference list)
for resource in ["punkt", "punkt_tab", "stopwords", "wordnet", "omw-1.4"]:
    try:
        nltk.download(resource, quiet=True)
    except Exception:
        pass

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

print("music21:", music21.__version__)
print("gensim available:", Word2Vec is not None)
# Out:
# music21: 10.5.0
# gensim available: True

# %% [markdown]
# ## 2. Data Acquisition

# %%
# ---------------------------------------------------------------------------
# 2.1 Kaggle API authentication
# ---------------------------------------------------------------------------
import os

# Kaggle Credentials
os.environ["KAGGLE_USERNAME"] = "KGAT_5b91ead9128243f7620aff08a037f979"
os.environ["KAGGLE_KEY"] = "KGAT_5b91ead9128243f7620aff08a037f979"

# Install the kaggle CLI/package if it isn't already available
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "kaggle"])

print("Kaggle credentials configured for user:", os.environ.get("KAGGLE_USERNAME"))
# Out:
# Kaggle credentials configured for user: KGAT_5b91ead9128243f7620aff08a037f979

# %%
# ---------------------------------------------------------------------------
# 2.2 Download and unzip the dataset via the Kaggle API
# ---------------------------------------------------------------------------
import subprocess

DATA_DIR = "data/raw"
os.makedirs(DATA_DIR, exist_ok=True)

result = subprocess.run(
    ["kaggle", "datasets", "download",
     "-d", "blanderbuss/midi-classic-music",
     "-p", DATA_DIR,
     "--unzip"],
    capture_output=True, text=True
)

print(result.stdout)
if result.returncode != 0:
    print("STDERR:", result.stderr)
    raise RuntimeError(
        "Kaggle download failed. Common causes: (1) invalid/expired API key, "
        "(2) you have not accepted the dataset's terms on the Kaggle website "
        "(visit the dataset page and click 'Download' once manually to accept), "
        "(3) missing internet access — on Kaggle Notebooks, enable "
        "Settings -> Internet -> On."
    )

DATA_ROOT = DATA_DIR
print("\nDownload complete. Sample of files in", DATA_ROOT, ":")
print(os.listdir(DATA_ROOT)[:20])
# Out:
# Dataset URL: https://www.kaggle.com/datasets/blanderbuss/midi-classic-music
# License(s): unknown
# Downloading midi-classic-music.zip to data/raw
#
#
#
# Download complete. Sample of files in data/raw :
# ['Tchaikovsky Lake Of The Swans Act 1 6mov.mid', 'Arndt', 'Rothchild Symphony Rmw12 2mov.mid', 'Tchaicovsky Waltz of the Flowers.MID', 'Tchaikovsky Lake Of The Swans Act 2 14mov.mid', 'Tchaikovsky Lake Of The Swans Act 1 4mov.mid', 'Albe╠üniz', 'Tchaikovsky Lake Of The Swans Act 2 10mov.mid', 'Tchaikovsky Lake Of The Swans Act 1 2mov.mid', 'midiclassics', 'Tchaikovsky Lake Of The Swans Act 2 12mov.mid', 'Alkan', 'Rothchlid Symphony Rmw12 3mov.mid', 'Tchaikovsky Lake Of The Swans Act 1 7-8movs.mid', 'Sibelius Kuolema Vals op44.mid', 'Wagner Ride of the valkyries.mid', 'Tchaikovsky Lake Of The Swans Act 1 5mov.mid', 'Tchaikovsky Lake Of The Swans Act 1 9mov.mid', 'Tchaikovsky Lake Of The Swans Act 1 1mov.mid', 'Arensky']

# %%
# ---------------------------------------------------------------------------
# 2.3 Discover and label MIDI files
# ---------------------------------------------------------------------------
import glob
import pandas as pd

COMPOSERS = ["bach", "beeth", "chopin", "mozart"]

DATA_ROOT = "data/raw"

def discover_midi_files(root_dir, composers):
    """Recursively discover .mid/.midi files and label each by composer,
    matching either a per-composer subfolder structure or a composer name
    embedded in the filename/path."""
    all_midi = glob.glob(os.path.join(root_dir, "**", "*.mid"), recursive=True)
    all_midi += glob.glob(os.path.join(root_dir, "**", "*.midi"), recursive=True)

    records = []
    for path in all_midi:
        lower_path = path.lower()
        print(lower_path)
        for composer in composers:
            if composer.lower() in lower_path:
                records.append({
                    "filepath": path,
                    "composer": composer,
                    "filename": os.path.basename(path),
                })
                break
    return pd.DataFrame(records)

file_manifest = discover_midi_files(DATA_ROOT, COMPOSERS)
print(f"Discovered {len(file_manifest)} labeled MIDI files.")
file_manifest["composer"].value_counts()
# Out:
# data/raw/tchaikovsky lake of the swans act 1 6mov.mid
# data/raw/rothchild symphony rmw12 2mov.mid
# data/raw/tchaikovsky lake of the swans act 2 14mov.mid
# data/raw/tchaikovsky lake of the swans act 1 4mov.mid
# data/raw/tchaikovsky lake of the swans act 2 10mov.mid
# data/raw/tchaikovsky lake of the swans act 1 2mov.mid
# data/raw/tchaikovsky lake of the swans act 2 12mov.mid
# data/raw/rothchlid symphony rmw12 3mov.mid
# data/raw/tchaikovsky lake of the swans act 1 7-8movs.mid
# data/raw/sibelius kuolema vals op44.mid
# data/raw/wagner ride of the valkyries.mid
# data/raw/tchaikovsky lake of the swans act 1 5mov.mid
# data/raw/tchaikovsky lake of the swans act 1 9mov.mid
# data/raw/tchaikovsky lake of the swans act 1 1mov.mid
# data/raw/tchaikovsky lake of the swans act 2 11mov.mid
# data/raw/tchaikovsky lake of the swans act 2 13mov.mid
# data/raw/tchaikovsky lake of the swans act 1 3mov.mid
# data/raw/arndt/nola, novelty piano solo.mid
# data/raw/albe╠üniz/espana op. 165.mid
# data/raw/albe╠üniz/torre bermeja serenata from piezas caracteristicas.mid
# data/raw/albe╠üniz/triana.mid
# data/raw/albe╠üniz/cataluna (curranda), no.2 from suite espanola.mid
# data/raw/albe╠üniz/aragon (fantasia) op.47 part 6.mid
# data/raw/albe╠üniz/castilla (seguidillas) op.47 part 7.mid
# data/raw/albe╠üniz/piezas caracteristicas, gavotte.mid
# data/raw/albe╠üniz/ti╠ütulo desconocido 2.mid
# data/raw/albe╠üniz/ti╠ütulo desconocido 3.mid
# data/raw/albe╠üniz/mallorca (barcarola).mid
# data/raw/albe╠üniz/catalun╠âa (curranda), no.2 from suite espanola.mid
# data/raw/albe╠üniz/ti╠ütulo desconocido 4.mid
# data/raw/albe╠üniz/ti╠ütulo desconocido.mid
# data/raw/albe╠üniz/espan╠âa op. 165 no.6.mid
# data/raw/albe╠üniz/espan╠âa op. 165 no.4.mid
# data/raw/albe╠üniz/espan╠âa op. 165 no.5.mid
# data/raw/albe╠üniz/espan╠âa op. 165 no.1.mid
# data/raw/albe╠üniz/suite espanola no.5. asturias.mid
# data/raw/albe╠üniz/espan╠âa op. 165 no.2.mid
# data/raw/albe╠üniz/espan╠âa op. 165 no.3.mid
# data/raw/midiclassics/rothchild piano sonata rmw13 2mov.mid
# data/raw/midiclassics/liszt bach prelude transcription.mid
# data/raw/midiclassics/diabelli sonatina op151 n1 2mov.mid
# data/raw/midiclassics/liszt paganini etude n5.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 6mov.mid
# data/raw/midiclassics/rothchild symphony rmw12 2mov.mid
# data/raw/midiclassics/ginastera estancia.mid
# data/raw/midiclassics/bizet carmen prelude.mid
# data/raw/midiclassics/rothchild horn concerto rmw16 3mov.mid
# data/raw/midiclassics/kuhlau sonatina op55 n3 1mov.mid
# data/raw/midiclassics/reinecke piano concerto n3 1mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n2 1mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n3 1mov.mid
# data/raw/midiclassics/buxethude buxwv138 prelude.mid
# data/raw/midiclassics/rothchild horn concerto rmw16 1mov.mid
# data/raw/midiclassics/liszt paganini etude n3.mid
# data/raw/midiclassics/liszt paganini etude n2.mid
# data/raw/midiclassics/debussy suite bergamasque 2mov.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 2 14mov.mid
# data/raw/midiclassics/dvorak symphony op70 n7 2mov.mid
# data/raw/midiclassics/reinecke piano concerto n3 3mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n2 3mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n3 3mov.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 4mov.mid
# data/raw/midiclassics/rothchild oboe concerto rmw09 2mov.mid
# data/raw/midiclassics/liszt paganini etude n1.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 2 10mov.mid
# data/raw/midiclassics/grieg piano concerto op16 1mov.mid
# data/raw/midiclassics/bizet symphony in c 1mov.mid
# data/raw/midiclassics/gershuin rhapsody in blue piano duet.mid
# data/raw/midiclassics/kuhlau sonatina op60 n2.mid
# data/raw/midiclassics/kuhlau sonatina op60 n3.mid
# data/raw/midiclassics/buxethude buxwv157 toccata.mid
# data/raw/midiclassics/bartok suite 1mov.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 2mov.mid
# data/raw/midiclassics/debussy suite bergamasque 4mov.mid
# data/raw/midiclassics/bizet symphony in c 3mov.mid
# data/raw/midiclassics/dvorak symphony op70 n7 4mov.mid
# data/raw/midiclassics/nicolai overture the merry wives of windsor.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 2 12mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n4 1mov.mid
# data/raw/midiclassics/rimsky korsakov ''flight of the bumblebee''.mid
# data/raw/midiclassics/dvorak symphony op70 n7 1mov.mid
# data/raw/midiclassics/debussy suite bergamasque 1mov.mid
# data/raw/midiclassics/rothchild horn concerto rmw16 2mov.mid
# data/raw/midiclassics/rothchlid symphony rmw12 3mov.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 7-8movs.mid
# data/raw/midiclassics/kuhlau sonatina op20 n1.mid
# data/raw/midiclassics/sibelius kuolema vals op44.mid
# data/raw/midiclassics/rothchild piano sonata rmw13 3mov.mid
# data/raw/midiclassics/rothchild oboe concerto rmw09 1mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n1 3mov.mid
# data/raw/midiclassics/buxethude buxwv155 toccata.mid
# data/raw/midiclassics/wagner ride of the valkyries.mid
# data/raw/midiclassics/rothchild symphony rmw12 1mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n1 1mov.mid
# data/raw/midiclassics/buxethude buxwv162 prelude.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 5mov.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 9mov.mid
# data/raw/midiclassics/meditation thais.mid
# data/raw/midiclassics/rothchild piano sonata rmw13 1mov.mid
# data/raw/midiclassics/rothchild oboe concerto rmw09 3mov.mid
# data/raw/midiclassics/debussy suite bergamasque 3mov.mid
# data/raw/midiclassics/pollen beguine royale.mid
# data/raw/midiclassics/diabelli sonatina op151 n3 2mov.mid
# data/raw/midiclassics/diabelli sonatina op151 n2 2mov.mid
# data/raw/midiclassics/bizet symphony in c 4mov.mid
# data/raw/midiclassics/reinecke piano concerto n3 2mov.mid
# data/raw/midiclassics/dvorak symphony op70 n7 3mov.mid
# data/raw/midiclassics/buxethude buxwv158 preambulum.mid
# data/raw/midiclassics/buxethude buxwv145 prelude.mid
# data/raw/midiclassics/pachebel toccata n1.mid
# data/raw/midiclassics/buxethude buxwv136 prelude.mid
# data/raw/midiclassics/buxethude buxwv167 canzonetta.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 1mov.mid
# data/raw/midiclassics/buxethude buxwv161 passcaglia.mid
# data/raw/midiclassics/bartok suite 2mov.mid
# data/raw/midiclassics/dvorak slavonic dance n8.mid
# data/raw/midiclassics/pachebel toccata n2.mid
# data/raw/midiclassics/diabelli sonatina op151 n4 2mov.mid
# data/raw/midiclassics/c.p.e.bach solfeggieto.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 2 11mov.mid
# data/raw/midiclassics/buxethude buxwv153 prelude.mid
# data/raw/midiclassics/reger burlesque op58 n3.mid
# data/raw/midiclassics/pachebel toccata n3.mid
# data/raw/midiclassics/pachebel toccata n7.mid
# data/raw/midiclassics/dvorak trio op26.mid
# data/raw/midiclassics/buxethude buxwv156 toccata.mid
# data/raw/midiclassics/lizt piano concerto n1 s124.mid
# data/raw/midiclassics/kuhlau sonatina op55 n1.mid
# data/raw/midiclassics/buxethude buxwv160 ciacona.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 2 13mov.mid
# data/raw/midiclassics/reger burlesque op58 n6.mid
# data/raw/midiclassics/bizet symphony in c 2mov.mid
# data/raw/midiclassics/pachebel toccata n4.mid
# data/raw/midiclassics/tchaikovsky lake of the swans act 1 3mov.mid
# data/raw/midiclassics/buxethude buxwv157 tocatta and fugue.mid
# data/raw/midiclassics/liszt ab irato ''the perfect etude'' s143 r4b.mid
# data/raw/midiclassics/grieg piano concerto 2mov.mid
# data/raw/midiclassics/reger burlesque op58 n5.mid
# data/raw/midiclassics/griffes/the vale of dreams.mid
# data/raw/midiclassics/griffes/the night winds.mid
# data/raw/midiclassics/griffes/the white peacock.mid
# data/raw/midiclassics/griffes/scherzo, op.6 no.3.mid
# data/raw/midiclassics/griffes/the fountain of the aqua paola.mid
# data/raw/midiclassics/mozart/k495 horn concerto n4 1mov.mid
# data/raw/midiclassics/mozart/k626 requiem 05 recordare.mid
# data/raw/midiclassics/mozart/k492 overture ''le nozze di figaro''.mid
# data/raw/midiclassics/mozart/k427 great mass 1mov.mid
# data/raw/midiclassics/mozart/k299 flute harp concerto 3mov.mid
# data/raw/midiclassics/mozart/viennese sonatinas k439b n2 3mov.mid
# data/raw/midiclassics/mozart/k525 serenade 2mov ''eine kleine natchmusik''.mid
# data/raw/midiclassics/mozart/k314 flute concerto n2 3mov.mid
# data/raw/midiclassics/mozart/k317 coronation mass 2mov.mid
# data/raw/midiclassics/mozart/k401 fuga in g minor .mid
# data/raw/midiclassics/mozart/a piece for piano,k.176.mid
# data/raw/midiclassics/mozart/k626 requiem 06 confutatis.mid
# data/raw/midiclassics/mozart/k136 divertimento 2mov.mid
# data/raw/midiclassics/mozart/sonatina n3 2mov.mid
# data/raw/midiclassics/mozart/k546 adagio & fugue for strings.mid
# data/raw/midiclassics/mozart/k335 laudate dominus.mid
# data/raw/midiclassics/mozart/k626 requiem kyrie.mid
# data/raw/midiclassics/mozart/rondo in c.mid
# data/raw/midiclassics/mozart/k626 requiem 09 hostias.mid
# data/raw/midiclassics/mozart/sonatina n22 4mov.mid
# data/raw/midiclassics/mozart/k495 horn concerto n4 3mov.mid
# data/raw/midiclassics/mozart/k314 flute concerto n2 1mov.mid
# data/raw/midiclassics/mozart/k02 minuet in f.mid
# data/raw/midiclassics/mozart/viennese sonatinas k439b n2 1mov.mid
# data/raw/midiclassics/mozart/k299 flute harp concerto 1mov.mid
# data/raw/midiclassics/mozart/contradance n2.mid
# data/raw/midiclassics/mozart/viennese sonatinas k439b n6 2mov.mid
# data/raw/midiclassics/mozart/sonatina n21 3mov.mid
# data/raw/midiclassics/mozart/fantasia in d, k397.mid
# data/raw/midiclassics/mozart/k317 coronation mass 4mov.mid
# data/raw/midiclassics/mozart/k626 requiem 08 offertorio domine jesu.mid
# data/raw/midiclassics/mozart/k525 serenade 3mov ''eine kleine natchmusik''.mid
# data/raw/midiclassics/mozart/contradance n3.mid
# data/raw/midiclassics/mozart/k117 offertorio jubilate deo.mid
# data/raw/midiclassics/mozart/contradance n1.mid
# data/raw/midiclassics/mozart/k594 adagio & allegro for mechanical organ.mid
# data/raw/midiclassics/mozart/k622 clarinet concerto 2mov.mid
# data/raw/midiclassics/mozart/k573 9 variations for piano uber duport.mid
# data/raw/midiclassics/mozart/k191 bassoon concerto 2mov.mid
# data/raw/midiclassics/mozart/k04 minuet in f.mid
# data/raw/midiclassics/mozart/vesperae solemnes de confessore ''vespers'' k339 1 dixit dominus.mid
# data/raw/midiclassics/mozart/k05 minuet for harpsichord.mid
# data/raw/midiclassics/mozart/k525 serenade 1mov ''eine kleine natchmusik''.mid
# data/raw/midiclassics/mozart/k618 ave verum corpus.mid
# data/raw/midiclassics/mozart/k317 coronation mass 6mov.mid
# data/raw/midiclassics/mozart/sonatina n3 1mov.mid
# data/raw/midiclassics/mozart/k136 divertimento 3mov.mid
# data/raw/midiclassics/mozart/k317 coronation mass 3mov.mid
# data/raw/midiclassics/mozart/k626 requiem 04 dies irae.mid
# data/raw/midiclassics/mozart/k626 requiem 10 sanctus.mid
# data/raw/midiclassics/mozart/k527 overture ''don giovanni''.mid
# data/raw/midiclassics/mozart/k299 flute harp concerto 2mov.mid
# data/raw/midiclassics/mozart/viennese sonatinas k439b n2 2mov.mid
# data/raw/midiclassics/mozart/k314 flute concerto n2 2mov.mid
# data/raw/midiclassics/mozart/k393 solfeggi n4.mid
# data/raw/midiclassics/mozart/k393 solfeggi n5.mid
# data/raw/midiclassics/mozart/k501 andante with 5 variations for piano duet.mid
# data/raw/midiclassics/mozart/k393 solfeggi n1.mid
# data/raw/midiclassics/mozart/k354 piano variations ''je suis lindor''.mid
# data/raw/midiclassics/mozart/k495 horn concerto n4 2mov.mid
# data/raw/midiclassics/mozart/k617 adagio.mid
# data/raw/midiclassics/mozart/k136 divertimento 1mov.mid
# data/raw/midiclassics/mozart/k626 requiem 11 benedictus.mid
# data/raw/midiclassics/mozart/sonatina n3 3mov.mid
# data/raw/midiclassics/mozart/k398 piano variations ''salve tu domine''.mid
# data/raw/midiclassics/mozart/k393 solfeggi n2.mid
# data/raw/midiclassics/mozart/k393 solfeggi n3.mid
# data/raw/midiclassics/mozart/k626 requiem 01 introitus & kyrie.mid
# data/raw/midiclassics/mozart/k317 coronation mass 1mov.mid
# data/raw/midiclassics/mozart/k622 clarinet concerto 3mov.mid
# data/raw/midiclassics/mozart/k361 serenade n10 3mov.mid
# data/raw/midiclassics/mozart/k620 overture the magic flute.mid
# data/raw/midiclassics/mozart/rondo.mid
# data/raw/midiclassics/mozart/k626 requiem 03 tuba mirum.mid
# data/raw/midiclassics/mozart/viennese sonatinas k439b n2 4mov.mid
# data/raw/midiclassics/mozart/adagio in b flat.mid
# data/raw/midiclassics/mozart/k191 bassoon concerto 1mov.mid
# data/raw/midiclassics/mozart/another piece for piano,k.176.mid
# data/raw/midiclassics/mozart/k317 coronation mass 5mov.mid
# data/raw/midiclassics/mozart/k626 requiem 02 rextremendae.mid
# data/raw/midiclassics/mozart/k626 requiem 12 agnus dei.mid
# data/raw/midiclassics/mozart/fantasia in c k.475.mid
# data/raw/midiclassics/mozart/k339 vesperae solemnes de confessore (vespers) 1mov dixit dominus.mid
# data/raw/midiclassics/mozart/k626 requiem 07 lacrimosa.mid
# data/raw/midiclassics/mozart/viennese sonatinas k439b n6 1mov.mid
# data/raw/midiclassics/mozart/k03 allegro in bb.mid
# data/raw/midiclassics/mozart/k608 fantasia for mechanical organ.mid
# data/raw/midiclassics/mozart/k622 clarinet concerto 1mov.mid
# data/raw/midiclassics/mozart/k191 bassoon concerto 3mov.mid
# data/raw/midiclassics/mozart/k525 serenade 4mov ''eine kleine natchmusik''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n22 k162 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n37 k444 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n31 k297 2mov ''paris''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n28 k200 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n25 k183 4mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n33 k319 4mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n29 k201 4mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n30 k202 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n40 k550 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n39 k543 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n30 k202 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n40 k550 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n36 k425 2mov ''linz''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n22 k162 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n41 k551 3mov ''jupiter''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n28 k200 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n39 k543 4mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n31 k297 3mov ''paris''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n4 k19 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n33 k319 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n25 k183 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n29 k201 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n36 k425 3mov ''linz''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n34 k338 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n34 k338 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n36 k425 4mov ''linz''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n4 k019 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n35 k385 3mov ''haffner''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n39 k543 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n30 k202 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n35 k385 2mov ''haffner''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n38 k504 2mov ''prague''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n36 k425 1mov ''linz''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n28 k200 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n41 k551 4mov ''jupiter''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n5 k022.mid
# data/raw/midiclassics/mozart/symphonies/symphony n35 k385 1mov ''haffner''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n40 k550 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n38 k504 3mov ''prague''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n39 k543 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n33 k319 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n41 k551 2mov ''jupiter''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n25 k183 3mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n30 k202 4mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n31 k297 1mov ''paris''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n35 k385 4mov ''haffner''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n29 k201 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n25 k183 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n33 k319 1mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n41 k551 1mov ''jupiter''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n40 k550 4mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n38 k504 1mov ''prague''.mid
# data/raw/midiclassics/mozart/symphonies/symphony n34 k338 2mov.mid
# data/raw/midiclassics/mozart/symphonies/symphony n28 k200 4mov.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n5 country dance.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n4 minuet.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n6 llittle minuet.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n12 rondino.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n20 presto.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n19 giga.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n7 country dance.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n17 siciliano.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n16 minuet.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n13 prelude.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n8 minuet.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n10 air.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n11 country dance.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n1 andante.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n2 minuet.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n9 allegretto.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n14 rondo.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n3 little march.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n15 andantino.mid
# data/raw/midiclassics/mozart/the chelsea notebook/early pieces n18 little song.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n03 k281.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n14 k457.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n02 k280.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n15 k593-494.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n04 k282.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n13 k333.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n12 k332.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n05 k283.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n17 k547a.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n01 k279.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n07 k309.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n18 k570.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n16 k545.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n10 k330.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n11 k331.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n06 k284.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n19 k576.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n08 k311.mid
# data/raw/midiclassics/mozart/piano sonatas/piano sonata n09 k310.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k281 piano sonata n03 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k331 piano sonata n11 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k497 piano sonata 4 hands.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k521 piano sonata 4 hands.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k332 piano sonata n12 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k279 piano sonata n01 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k358 piano sonata 4 hands.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k381 piano sonata 4 hands.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k333 piano sonata n13 .mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k457 piano sonata n14 .mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k309 piano sonata n10 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k332 piano sonata n12 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k282 piano sonata n04 .mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k570 piano sonata 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k280 piano sonata n02 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k576 piano sonata n19 .mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k280 piano sonata n02 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k330 piano sonata n10 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k333 piano sonata n13 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k19d piano sonata duet.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k279 piano sonata n01 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k309 piano sonata n10 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k332 piano sonata n12 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k281 piano sonata n03 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k309 piano sonata n10 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k545 piano sonata.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k281 piano sonata n03 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k279 piano sonata n01 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k357 piano sonata 4 hands.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k331 piano sonata n11 .mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k333 piano sonata n13 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k330 piano sonata n10 1mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k570 piano sonata 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k333 piano sonata n13 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k284 piano sonata n06 .mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k330 piano sonata n10 3mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k280 piano sonata n02 2mov.mid
# data/raw/midiclassics/mozart/piano sonatas/nueva carpeta/k570 piano sonata 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n12 k414 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n7 for 3 pianos k242 1mov ''lodron''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n21 k467 2mov ''elvira madigan''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n24 k491 2mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n17 k453 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n12 k414 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n16 k451 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n20 k466 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n18 k456 1mov ''paradis''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n14 k449 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n6 k238 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n26 k537 2mov ''coronation''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n7 for 3 pianos k242 3mov ''lodron''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n23 k488 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n6 k238 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n25 k503 2mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n23 k488 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n18 k456 2mov ''paradis''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n20 k466 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n16 k451 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n7 for 3 pianos k242 2mov ''lodron''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n14 k449 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n24 k491 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n8 k246 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n18 k456 3mov ''paradis''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n21 k467 1mov ''elvira madigan''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n24 k491 3mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n8 k246 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n26 k537 3mov ''coronation''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n25 k503 1mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n14 k449 2mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n20 k466 2mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n21 k467 3mov ''elvira madigan''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n26 k537 1mov ''coronation''.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n23 k488 2mov.mid
# data/raw/midiclassics/mozart/piano concertos/piano concerto n25 k503 3mov.mid
# data/raw/midiclassics/durand, e/air de ballet.mid
# data/raw/midiclassics/satie/gnossie`nne no.1.mid
# data/raw/midiclassics/satie/ogive no.2.mid
# data/raw/midiclassics/satie/ogive no.3.mid
# data/raw/midiclassics/satie/gnossie`nne no.2.mid
# data/raw/midiclassics/satie/ogive no.1.mid
# data/raw/midiclassics/satie/le piccadilly.mid
# data/raw/midiclassics/satie/gnossie`nne no.3.mid
# data/raw/midiclassics/satie/ogive no.4.mid
# data/raw/midiclassics/satie/gnossie`nne no.6.mid
# data/raw/midiclassics/satie/gnossie`nne no.4.mid
# data/raw/midiclassics/satie/gnossie`nne no.5.mid
# data/raw/midiclassics/satie/cinq grimaces pour le songe d'une d'e'te', no.1. pre'ambule.mid
# data/raw/midiclassics/satie/cinq grimaces pour le songe d'une d'e'te', no.2. coquecigrue.mid
# data/raw/midiclassics/satie/cinq grimaces pour le songe d'une d'e'te', no.4. fanfaronnade.mid
# data/raw/midiclassics/satie/gymnopedie no.3.mid
# data/raw/midiclassics/satie/cinq grimaces pour le songe d'une d'e'te', no.5. pour sortir.mid
# data/raw/midiclassics/satie/cinq grimaces pour le songe d'une d'e'te', no.3. chasse.mid
# data/raw/midiclassics/satie/danse de travers no 1.mid
# data/raw/midiclassics/satie/gymnopedie no.1.mid
# data/raw/midiclassics/satie/sarabande no.3.mid
# data/raw/midiclassics/satie/la diva de l'empire.mid
# data/raw/midiclassics/satie/sarabande no.2.mid
# data/raw/midiclassics/satie/sarabande no.1.mid
# data/raw/midiclassics/arndt/nola, novelty piano solo.mid
# data/raw/midiclassics/skriabin/mazurka opus.3.mid
# data/raw/midiclassics/skriabin/mazurka opus.2.mid
# data/raw/midiclassics/skriabin/prelude opus,11, no.1.mid
# data/raw/midiclassics/skriabin/mazurka opus.1.mid
# data/raw/midiclassics/skriabin/mazurka opus.30, no.4.mid
# data/raw/midiclassics/skriabin/prelude opus,11, no.6.mid
# data/raw/midiclassics/skriabin/mazurka opus.5.mid
# data/raw/midiclassics/skriabin/etude opus 8 no 5.mid
# data/raw/midiclassics/skriabin/mazurka opus.21.mid
# data/raw/midiclassics/skriabin/mazurka opus.33, no4.mid
# data/raw/midiclassics/skriabin/mazurka opus.24 no.4.mid
# data/raw/midiclassics/skriabin/mazurka opus.25.mid
# data/raw/midiclassics/skriabin/mazurka opus.24 no.1.mid
# data/raw/midiclassics/skriabin/mazurka opus.25, no.3.mid
# data/raw/midiclassics/skriabin/mazurka opus.24 no.3.mid
# data/raw/midiclassics/skriabin/mazurka opus.24 no.2.mid
# data/raw/midiclassics/skriabin/etude op 2 no 1.mid
# data/raw/midiclassics/skriabin/mazurka opus.17.mid
# data/raw/midiclassics/skriabin/prelude opus,11, no.11.mid
# data/raw/midiclassics/skriabin/prelude opus,13, no.2.mid
# data/raw/midiclassics/skriabin/prelude opus,13, no.3.mid
# data/raw/midiclassics/skriabin/mazurka opus.25, no.9.mid
# data/raw/midiclassics/skriabin/prelude opus,11, no.14.mid
# data/raw/midiclassics/skriabin/prelude opus,11, no.15.mid
# data/raw/midiclassics/skriabin/flammes sombres opus.73, no.2.mid
# data/raw/midiclassics/skriabin/etude opus 8 no.2.mid
# data/raw/midiclassics/skriabin/flammes sombres opus.73, no.1.mid
# data/raw/midiclassics/skriabin/prelude opus,42 no.5.mid
# data/raw/midiclassics/skriabin/prelude opus,42 no.4.mid
# data/raw/midiclassics/skriabin/mazurka opus.33, no.2.mid
# data/raw/midiclassics/skriabin/etude opus 8 no 12.mid
# data/raw/midiclassics/jakobowski/the overture from the comic opera erminie.mid
# data/raw/midiclassics/jakobowski/lullaby.mid
# data/raw/midiclassics/chopin/finale to b minor paino sonata.mid
# data/raw/midiclassics/chopin/ecossaise no.2 in g.mid
# data/raw/midiclassics/chopin/mazurka op68 n2 drchew.mid
# data/raw/midiclassics/chopin/prelude n10 op28 ''the night moth''.mid
# data/raw/midiclassics/chopin/piano concerto n1 op11 2mov.mid
# data/raw/midiclassics/chopin/scherzo no.2, opus.31.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.8.mid
# data/raw/midiclassics/chopin/nocturne op32 n1.mid
# data/raw/midiclassics/chopin/prelude n17 op28 ''scene on the place of notre dame.mid
# data/raw/midiclassics/chopin/prelude n21 op28 ''sunday''.mid
# data/raw/midiclassics/chopin/waltz op70 n2.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.9.mid
# data/raw/midiclassics/chopin/nocturne op32 n2.mid
# data/raw/midiclassics/chopin/etude op25 n09.mid
# data/raw/midiclassics/chopin/mazurka op67 n3 drchew.mid
# data/raw/midiclassics/chopin/op.53 'polonaise in a flat' heroic.mid
# data/raw/midiclassics/chopin/impromptu n3 op51.mid
# data/raw/midiclassics/chopin/etude op25 n08.mid
# data/raw/midiclassics/chopin/nocturne no.15 in f minor opus.55 -1.mid
# data/raw/midiclassics/chopin/prelude n05 op28 ''uncertainty''.mid
# data/raw/midiclassics/chopin/polonaise opus.40, no.1 (military).mid
# data/raw/midiclassics/chopin/piano concerto n2 1mov.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.19.mid
# data/raw/midiclassics/chopin/mazurka op7 n1.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.18.mid
# data/raw/midiclassics/chopin/nocturne op55 n1.mid
# data/raw/midiclassics/chopin/etude no.2 in a minor.mid
# data/raw/midiclassics/chopin/winter wind etude.mid
# data/raw/midiclassics/chopin/prelude n01 op28 ''reunion''.mid
# data/raw/midiclassics/chopin/prelude n06 op28 ''tolling bells''.mid
# data/raw/midiclassics/chopin/mazurka op7 n2.mid
# data/raw/midiclassics/chopin/nocturne op55 n2.mid
# data/raw/midiclassics/chopin/tarantella.mid
# data/raw/midiclassics/chopin/waltz op64 n1.mid
# data/raw/midiclassics/chopin/etude no.1.mid
# data/raw/midiclassics/chopin/prelude n20 op28 ''funeral march''.mid
# data/raw/midiclassics/chopin/etude op25 n12 ''the ocean''.mid
# data/raw/midiclassics/chopin/sonata op35 n1 .mid
# data/raw/midiclassics/chopin/imprompt fantastique.mid
# data/raw/midiclassics/chopin/piano concerto n2 3mov.mid
# data/raw/midiclassics/chopin/fantasie impromptu op66.mid
# data/raw/midiclassics/chopin/etude op10 n08.mid
# data/raw/midiclassics/chopin/nocturne op37 01.mid
# data/raw/midiclassics/chopin/etude op10 n09.mid
# data/raw/midiclassics/chopin/trois nouvelles etudes (op.posth.).mid
# data/raw/midiclassics/chopin/prelude n16 op28 ''hades''.mid
# data/raw/midiclassics/chopin/2 polonaises op26 n1.mid
# data/raw/midiclassics/chopin/ballade no.2 in f major.mid
# data/raw/midiclassics/chopin/(2542)prelude opus.28, no.16 in b flat minor.mid
# data/raw/midiclassics/chopin/nocturne no.18 in e major op62.mid
# data/raw/midiclassics/chopin/etude op.10 no.11.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.10.mid
# data/raw/midiclassics/chopin/etude op10 n10.mid
# data/raw/midiclassics/chopin/grande waltz op18.mid
# data/raw/midiclassics/chopin/prelude n23 op28 ''a pleasure boat''.mid
# data/raw/midiclassics/chopin/etude op10 n05 ''black key''.mid
# data/raw/midiclassics/chopin/scherzo op31.mid
# data/raw/midiclassics/chopin/nocturne op33 n4.mid
# data/raw/midiclassics/chopin/etude op10 n11.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.11.mid
# data/raw/midiclassics/chopin/piano concerto n1 op11 3mov.mid
# data/raw/midiclassics/chopin/prelude n03 op28 ''thou art so like a flower''.mid
# data/raw/midiclassics/chopin/prelude op.28-15 raindrop.mid
# data/raw/midiclassics/chopin/nocturne no.1, opus.62.mid
# data/raw/midiclassics/chopin/prelude n07 op28 ''the polish dance''.mid
# data/raw/midiclassics/chopin/nocturne op15 n2.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.13.mid
# data/raw/midiclassics/chopin/etude op10 n07.mid
# data/raw/midiclassics/chopin/etude op10 n04 drchew.mid
# data/raw/midiclassics/chopin/etude op10 n06.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.12.mid
# data/raw/midiclassics/chopin/nocturne op15 n3.mid
# data/raw/midiclassics/chopin/prelude n15 op28 ''raindrop''.mid
# data/raw/midiclassics/chopin/sonata op35 n2 .mid
# data/raw/midiclassics/chopin/sonata op35 n3 .mid
# data/raw/midiclassics/chopin/nocturne op09 n2.mid
# data/raw/midiclassics/chopin/ballad op32.mid
# data/raw/midiclassics/chopin/etude op10 n02.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.16.mid
# data/raw/midiclassics/chopin/etude op25 n01 ''harp etude''.mid
# data/raw/midiclassics/chopin/waltz in ab (op.posth., brown21).mid
# data/raw/midiclassics/chopin/etude op. 10-5 black keys.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.17.mid
# data/raw/midiclassics/chopin/prelude n24 op28 ''the storm''.mid
# data/raw/midiclassics/chopin/etude op10 n03.mid
# data/raw/midiclassics/chopin/nocturne op33 n2.mid
# data/raw/midiclassics/chopin/prelude n02 op28 ''presentiment of death''.mid
# data/raw/midiclassics/chopin/nocturne op09 n3.mid
# data/raw/midiclassics/chopin/scherzo n1 op20.mid
# data/raw/midiclassics/chopin/revolutionary.mid
# data/raw/midiclassics/chopin/etude op10 n01.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.15.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.14.mid
# data/raw/midiclassics/chopin/piano concerto n1 op11 1mov.mid
# data/raw/midiclassics/chopin/prelude n04 op28 ''suffocation''.mid
# data/raw/midiclassics/chopin/prelude n22 op28 ''impatience''.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.7.mid
# data/raw/midiclassics/chopin/etude op25 n05.mid
# data/raw/midiclassics/chopin/prelude n08 op28 ''desparation''.mid
# data/raw/midiclassics/chopin/nocturne op37 n2.mid
# data/raw/midiclassics/chopin/prelude n09 op28 ''vision''.mid
# data/raw/midiclassics/chopin/sonata no.3 1st mov allegro.mid
# data/raw/midiclassics/chopin/prelude n13 op28 ''loss''.mid
# data/raw/midiclassics/chopin/nocturne op62 n2.mid
# data/raw/midiclassics/chopin/prelude n14 op28 ''fear''.mid
# data/raw/midiclassics/chopin/mazurka op30 n2 drchew.mid
# data/raw/midiclassics/chopin/etude op25 n10.mid
# data/raw/midiclassics/chopin/etude op25 n04.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.6.mid
# data/raw/midiclassics/chopin/sonata op35 n4 .mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.4.mid
# data/raw/midiclassics/chopin/prelude n11 op28 ''dragonfly''.mid
# data/raw/midiclassics/chopin/etude op25 n06.mid
# data/raw/midiclassics/chopin/prelude n19 op28.mid
# data/raw/midiclassics/chopin/etude op 25, no.1.mid
# data/raw/midiclassics/chopin/barcarolle in f sharp major.mid
# data/raw/midiclassics/chopin/etude op25 n07.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.5.mid
# data/raw/midiclassics/chopin/nocturne op48 n1.mid
# data/raw/midiclassics/chopin/prelude n18 op28 ''suicide''.mid
# data/raw/midiclassics/chopin/etude op25 n03.mid
# data/raw/midiclassics/chopin/nocturne op27 n1.mid
# data/raw/midiclassics/chopin/etude no.7 in c major opus.10, no.7.mid
# data/raw/midiclassics/chopin/etude op10 n12 ''revolutionary''.mid
# data/raw/midiclassics/chopin/piano concerto n2 2mov.mid
# data/raw/midiclassics/chopin/nocturne op72 n1.mid
# data/raw/midiclassics/chopin/etude op25 n02.mid
# data/raw/midiclassics/chopin/nocturne op48 n2.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.2.mid
# data/raw/midiclassics/chopin/prelude n12 op28 ''duel''.mid
# data/raw/midiclassics/chopin/nocturne op27 n2.mid
# data/raw/midiclassics/chopin/sonata no.3, 2nd mov, scherzo.mid
# data/raw/midiclassics/chopin/etude op25 n11 ''winter wind''.mid
# data/raw/midiclassics/chopin/ballad op53.mid
# data/raw/midiclassics/chopin/mazurka op33 n2 drchew.mid
# data/raw/midiclassics/chopin/19 polish songs, for solo voice and piano accomplements, no.3.mid
# data/raw/midiclassics/stravinski/russian dance from petroushka.mid
# data/raw/midiclassics/stravinski/symphony of psalms, mov.1.mid
# data/raw/midiclassics/stravinski/firebird done for flute.mid
# data/raw/midiclassics/stravinski/symphony of psalms, mov.2.mid
# data/raw/midiclassics/stravinski/symphony of psalms, mov.3.mid
# data/raw/midiclassics/stravinski/the rite of spring, mov.f.mid
# data/raw/midiclassics/stravinski/the rite of spring, mov.g.mid
# data/raw/midiclassics/stravinski/the rite of spring, mov.e.mid
# data/raw/midiclassics/stravinski/the rite of spring, mov.d.mid
# data/raw/midiclassics/stravinski/the rite of spring, mov.a.mid
# data/raw/midiclassics/stravinski/the rite of spring, mov.b.mid
# data/raw/midiclassics/taube/min a"lskling.mid
# data/raw/midiclassics/komzak/neues leben, opus 210.mid
# data/raw/midiclassics/lange/au revoir.mid
# data/raw/midiclassics/lange/promise of spring.mid
# data/raw/midiclassics/lange/child & cuckoo.mid
# data/raw/midiclassics/lange/from the long ago.mid
# data/raw/midiclassics/lange/blumenlied opus.39.mid
# data/raw/midiclassics/lange/vintage dance.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 14mov.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 06mov.mid
# data/raw/midiclassics/mendelsonn/piano wedding march.mid
# data/raw/midiclassics/mendelsonn/symphony op90 n4 4mov ''italian''.mid
# data/raw/midiclassics/mendelsonn/piano concerto n1 in op25 3mov.mid
# data/raw/midiclassics/mendelsonn/andante alla marcia.mid
# data/raw/midiclassics/mendelsonn/organ sonata n1.mid
# data/raw/midiclassics/mendelsonn/prelude.mid
# data/raw/midiclassics/mendelsonn/symphony op56 n3 4mov ''scottish''.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 02mov scherzo.mid
# data/raw/midiclassics/mendelsonn/symphony op90 n4 1mov ''italian''.mid
# data/raw/midiclassics/mendelsonn/songs without words op62 n4.mid
# data/raw/midiclassics/mendelsonn/organ sonata n2.mid
# data/raw/midiclassics/mendelsonn/organ sonata n3.mid
# data/raw/midiclassics/mendelsonn/songs without words op62 n5.mid
# data/raw/midiclassics/mendelsonn/ostinato.mid
# data/raw/midiclassics/mendelsonn/allegro brillant for piano 4-hands op92.mid
# data/raw/midiclassics/mendelsonn/'lieder ohne worte' book 1 op1 n1.mid
# data/raw/midiclassics/mendelsonn/andante.mid
# data/raw/midiclassics/mendelsonn/organ sonata n6.mid
# data/raw/midiclassics/mendelsonn/allegro n2.mid
# data/raw/midiclassics/mendelsonn/symphony op90 n4 2mov ''italian''.mid
# data/raw/midiclassics/mendelsonn/symphony op56 n3 1mov ''scottish''.mid
# data/raw/midiclassics/mendelsonn/symphony op56 n3 2mov ''scottish''.mid
# data/raw/midiclassics/mendelsonn/variations serieuses op54.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 04mov song with chorus.mid
# data/raw/midiclassics/mendelsonn/fantaisie and fugue.mid
# data/raw/midiclassics/mendelsonn/piano concerto n1 in op25 1mov.mid
# data/raw/midiclassics/mendelsonn/organ sonata n4.mid
# data/raw/midiclassics/mendelsonn/organ sonata n5.mid
# data/raw/midiclassics/mendelsonn/allegro n1.mid
# data/raw/midiclassics/mendelsonn/symphony op56 n3 3mov ''scottish''.mid
# data/raw/midiclassics/mendelsonn/songs without words op62 n3.mid
# data/raw/midiclassics/mendelsonn/choral 4.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 08mov ''nocturne''.mid
# data/raw/midiclassics/mendelsonn/allegro moderato.mid
# data/raw/midiclassics/mendelsonn/nachtspiel.mid
# data/raw/midiclassics/mendelsonn/songs without words op53 n5.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 15mov.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 07mov.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 05mov.mid
# data/raw/midiclassics/mendelsonn/symphony op107 n5 1mov ''reformation''.mid
# data/raw/midiclassics/mendelsonn/songs without words op30 n1.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 09mov.mid
# data/raw/midiclassics/mendelsonn/violin concerto op63.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 11 mov.mid
# data/raw/midiclassics/mendelsonn/'lieder ohne worte' book 2 op30 n3.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 12mov ''dance of clowns''.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 01mov overture.mid
# data/raw/midiclassics/mendelsonn/symphony op107 n5 3mov ''reformation''.mid
# data/raw/midiclassics/mendelsonn/prelude and fugue n3.mid
# data/raw/midiclassics/mendelsonn/prelude and fugue n2.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 03mov.mid
# data/raw/midiclassics/mendelsonn/midsummer night dream 10mov ''wedding march''.mid
# data/raw/midiclassics/mendelsonn/prelude 2.mid
# data/raw/midiclassics/vaughan/suite of six pieces - prelude.mid
# data/raw/midiclassics/vaughan/the lake in the mountains.mid
# data/raw/midiclassics/vaughan/folk songs from somerset.mid
# data/raw/midiclassics/vaughan/march (seventeen come sunday).mid
# data/raw/midiclassics/vaughan/slow dance.mid
# data/raw/midiclassics/vaughan/linden lea - a dorset song.mid
# data/raw/midiclassics/vaughan/my bonny boy.mid
# data/raw/midiclassics/vaughan/rondo.mid
# data/raw/midiclassics/vaughan/quick dance.mid
# data/raw/midiclassics/vaughan/pezzo ostinato.mid
# data/raw/midiclassics/vaughan/slow air.mid
# data/raw/midiclassics/pachelbel/werde munter mein gemute.mid
# data/raw/midiclassics/pachelbel/fantasy.mid
# data/raw/midiclassics/pachelbel/magnificat no.2, 08.mid
# data/raw/midiclassics/coleridge-taylor/no.1 le caprice de nannette.mid
# data/raw/midiclassics/coleridge-taylor/un sonnet d'armour no.3.mid
# data/raw/midiclassics/coleridge-taylor/la tarantelle fretillante.mid
# data/raw/midiclassics/coleridge-taylor/demande et reponse.mid
# data/raw/midiclassics/rossini/i gondolieri.mid
# data/raw/midiclassics/rossini/la danza.mid
# data/raw/midiclassics/czerny/etude op.740 no.18.mid
# data/raw/midiclassics/czerny/etude op.740 no.8.mid
# data/raw/midiclassics/czerny/etude op.740 no.9.mid
# data/raw/midiclassics/czerny/etude op.740 no.19.mid
# data/raw/midiclassics/czerny/etude op.740 no.27.mid
# data/raw/midiclassics/czerny/czerny op33 ''la ricordanza''.mid
# data/raw/midiclassics/czerny/etude op.299 no.07.mid
# data/raw/midiclassics/czerny/etude op.740 no.50.mid
# data/raw/midiclassics/czerny/etude op.740 no.44.mid
# data/raw/midiclassics/czerny/dancing the jig.mid
# data/raw/midiclassics/czerny/etude op.299 no.34.mid
# data/raw/midiclassics/czerny/czerny ''die schule der gelaufigkeit'' op299 n21.mid
# data/raw/midiclassics/czerny/etude op.740 no.11.mid
# data/raw/midiclassics/czerny/etude op.740 no.1.mid
# data/raw/midiclassics/czerny/etude op.740 no.10.mid
# data/raw/midiclassics/czerny/etude op.740 no.12.mid
# data/raw/midiclassics/czerny/etude op.740 no.2.mid
# data/raw/midiclassics/czerny/etude op.740 no.3.mid
# data/raw/midiclassics/czerny/etude op.740 no.13.mid
# data/raw/midiclassics/czerny/etude op.740 no.17.mid
# data/raw/midiclassics/czerny/etude op.740 no.7.mid
# data/raw/midiclassics/czerny/etude op.740 no.6.mid
# data/raw/midiclassics/czerny/etude op.740 no.16.mid
# data/raw/midiclassics/czerny/etude op.740 no.14.mid
# data/raw/midiclassics/czerny/etude op.740 no.4.mid
# data/raw/midiclassics/czerny/etude op.740 no.5.mid
# data/raw/midiclassics/czerny/etude op.740 no.15.mid
# data/raw/midiclassics/ravel/jeux d'eau.mid
# data/raw/midiclassics/ravel/cinq melodies populaires greaques no.2.mid
# data/raw/midiclassics/ravel/pavane pour une infante de'funte.mid
# data/raw/midiclassics/ravel/jeuxdeau suite.mid
# data/raw/midiclassics/ravel/cinq melodies populaires greaques no.3.mid
# data/raw/midiclassics/ravel/d'anne jouant de l'espinette.mid
# data/raw/midiclassics/ravel/cinq melodies populaires greaques no.1.mid
# data/raw/midiclassics/ravel/cinq melodies populaires greaques no.4.mid
# data/raw/midiclassics/ravel/cinq melodies populaires greaques no.5.mid
# data/raw/midiclassics/ravel/toccato for piano.mid
# data/raw/midiclassics/ravel/alborada del gracioso.mid
# data/raw/midiclassics/ravel/chansons 2, trois beaux oiseaux du paradis.mid
# data/raw/midiclassics/ravel/histoires naturelles, no.1 le paon.mid
# data/raw/midiclassics/finck/march of the crusaders.mid
# data/raw/midiclassics/durand, ma/premie`re valse, opus 83.mid
# data/raw/midiclassics/handel/air, hwv 471.mid
# data/raw/midiclassics/hiller/serenade in g major.mid
# data/raw/midiclassics/hiller/minuet in b flat.mid
# data/raw/midiclassics/copland/symphony no.3, mov.1.mid
# data/raw/midiclassics/copland/danza de jalisco.mid
# data/raw/midiclassics/copland/sunday traffic.mid
# data/raw/midiclassics/copland/the promise of living - from the tender land.mid
# data/raw/midiclassics/copland/fanfare for the common man.mid
# data/raw/midiclassics/burgmuller/study no.18, inquietude , opus.100.mid
# data/raw/midiclassics/burgmuller/study no.10, tendre fleur, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.11, la bergeronnette, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.12, l'adieu, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.3, la pastorale, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.17, la babilarde , opus.100.mid
# data/raw/midiclassics/burgmuller/study no.9, la hasse, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.1, la candeur, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.6, progres, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.22, barcarolle , opus.100.mid
# data/raw/midiclassics/burgmuller/-study no.6 opus.105.mid
# data/raw/midiclassics/burgmuller/-study no.1 opus.105.mid
# data/raw/midiclassics/burgmuller/study no.24, l'hirondelle, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.19, ave maria, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.23, le retour, opus.100.mid
# data/raw/midiclassics/burgmuller/-study no.7 opus.105.mid
# data/raw/midiclassics/burgmuller/study no.21, l'harmonie des anges, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.2, l'arabesque, opus.100.mid
# data/raw/midiclassics/burgmuller/-study no.5 opus.105.mid
# data/raw/midiclassics/burgmuller/-study no.2 opus.105.mid
# data/raw/midiclassics/burgmuller/study no.7, le courant limpide, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.25, la chevaleresque, opus.100.mid
# data/raw/midiclassics/burgmuller/study no.5, innocence, opus.100.mid
# data/raw/midiclassics/burgmuller/-study no.3 opus.105.mid
# ...
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/variatio.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/tanz5.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/tanz1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/podria.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/solfeggi.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sugarplm.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sonatain.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud13.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud07.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/symno84m.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud06.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud12.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/symph_5.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sonata01.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/rapinbl.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sho_fd_3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/varipaga.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/tribamer.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/starwar2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sonata03.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud04.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud10.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/p03c_maj.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/p23bmaj.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/p16gmin.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/scarl4.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sabredan.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud11.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/prelud05.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/psugg.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sonata02.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/pathetiq.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/p21b_maj.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/p22b_min.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/picture.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/sontina3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/p_z/p08e_min.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/5thsymp.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/5thsymph.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/1812over.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/76tubas.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/2ptinv1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/5thsym.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/5th3rdmv.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/2001_2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/5th1stmv.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/5th2ndmv.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/varios/76tmbons.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op10no1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuet_t.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mozmenu.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k531.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_08.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/marche.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/legrenzi.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n4.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n5.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_09.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_493_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/m_loc.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/opus6.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/imperial.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_493_3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jesjoy.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n7.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n6.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jesujoy.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_493_2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op10no3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_quarc.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mozquar.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/marcello.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jupiter.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mappari.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k127.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/min_g.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jesus.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mars.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op10no4.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mirlitns.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/nutcrack.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/opus27.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jsconcer.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/joy.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op10no5.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuet_g.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/nut1mrch.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/nightbal.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/lesmiz.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuetg_.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op27_2_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mycntry.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/merrywid.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op27_2_3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mstrhou_.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_67_04.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op27_2_2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent_8.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/laststa2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/ntbldmtn.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonlt23.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_6.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jeux-int.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/johnblow.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k150.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/overtriv.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonligh.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mozrtq1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/khan.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_67_01.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k151.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_7.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op25no9.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/laststar.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_5.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_67_03.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_67_02.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mzt-k117.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_4.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mntevrdi.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuetg.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuet1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k163.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mzrtk550.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/martinu.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuet0.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12_8.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonlt3z.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jasnf1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuet2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/midins.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/messiah.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuetbo.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mozartq1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k001.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k005.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op25no1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_478_2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/joyofman.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_nacht.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/lulbye.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/litsym.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/nut2fair.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op25mend.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_478_3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/k010.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op25no2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mz_478_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/leyenda.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invent8.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/osolemi_.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/lagrange.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/latra.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_01.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonlite.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mandolin.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invno3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/macabre.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_42_04.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/jesu.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mywind3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/nut0over.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_02.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/invmid.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonrvr4.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuetga.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/opus14.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonrvr5.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minboch.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_03.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/maz24_4.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_07.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/lichvod.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_42_03.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonrvr1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuet.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_42_02.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moon_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_06.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/mozk622.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/maz24_1.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/maz24_3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/juras_gm.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_04.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_10.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/lacucura.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minwltz.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/odetojoy.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonrvr2.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op12n8.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/moonrvr3.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuetg0.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/minuetdj.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_42_01.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/nbwaltz.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/op_68_05.mid
# data/raw/midiclassics/varios - ti'tulo desconocido/i_o/maz24_2.mid
# data/raw/midiclassics/ambroise/dance fantastique.mid
# data/raw/midiclassics/ambroise/polonaise (1905)..mid
# data/raw/midiclassics/faure/le jardin de dolly no.2.mid
# data/raw/midiclassics/faure/le jardin de dolly no.3.mid
# data/raw/midiclassics/faure/noctune.mid
# data/raw/midiclassics/faure/les roses d' ispahan.mid
# data/raw/midiclassics/faure/sicilienne, from the suite pelleas & melisande.mid
# data/raw/midiclassics/faure/spleen song.mid
# data/raw/midiclassics/faure/souvenirs de bayreuth.mid
# data/raw/midiclassics/faure/romance sans paroles.mid
# data/raw/midiclassics/faure/berceuse.mid
# data/raw/midiclassics/faure/cantique de jean racine.mid
# data/raw/midiclassics/faure/berceuse op.16 for flute and piano.mid
# data/raw/midiclassics/faure/fleur jetee.mid
# data/raw/midiclassics/faure/nocturne.mid
# data/raw/midiclassics/faure/requiem agnus dei.mid
# data/raw/midiclassics/faure/overture masque and bergamesque.mid
# data/raw/midiclassics/faure/dolly suite.mid
# data/raw/midiclassics/busoni/another version on bizets carmen.mid
# data/raw/midiclassics/busoni/fantasia nach j. s. bach.mid
# data/raw/midiclassics/busoni/sonatina no. 6 kammer-fantasie lber bizets carmen.mid
# data/raw/midiclassics/dussek/la consolation opus.62.mid
# data/raw/midiclassics/dussek/la chasse in f major.mid
# data/raw/midiclassics/dussek/piano sonata in d opus.47 no.1.mid
# data/raw/alkan/un nuit d'ete suite no. 1 from les mois sequenced.mid
# data/raw/alkan/saltarelle op. 23.mid
# data/raw/alkan/chantes op 38,no.1.mid
# data/raw/alkan/gros temps (foul weather) from  les mois , op. 74, bk. 4, no. 1.mid
# data/raw/alkan/etude op.35 no.5.mid
# data/raw/alkan/etude op.76 no.2.mid
# data/raw/alkan/etude op.76 no.3 for both hands.mid
# data/raw/alkan/hallelujah (psalm 150).mid
# data/raw/arensky/a fairy tale.mid
# data/raw/arensky/psalm 119.mid
# data/raw/ambroise/dance fantastique.mid
# data/raw/ambroise/polonaise (1905)..mid
# Discovered 1561 labeled MIDI files.
# composer
# bach      950
# mozart    259
# beeth     214
# chopin    138
# Name: count, dtype: int64

# %%
# ---------------------------------------------------------------------------
# 2.4 Sampling cap for a tractable first pass (raise/remove for final run)
# ---------------------------------------------------------------------------
MAX_FILES_PER_COMPOSER = 80

# pandas 3.0 note: groupby(...).apply() now DROPS the grouping column, which
# silently removes "composer". Build the capped sample with an explicit
# per-group loop instead — functionally identical, preserves all columns.
file_manifest = (
    pd.concat([
        g.sample(min(len(g), MAX_FILES_PER_COMPOSER), random_state=SEED)
        for _, g in file_manifest.groupby("composer")
    ])
    .reset_index(drop=True)
)

print(f"Working corpus size after cap: {len(file_manifest)}")
file_manifest.to_csv("file_manifest.csv", index=False)
file_manifest.head()
# Out:
# Working corpus size after cap: 320
#                                             filepath composer  \
# 0  data/raw/midiclassics/Bach/Concertos/Bwv1043 T...     bach
# 1  data/raw/midiclassics/Varios - Ti'tulo descono...     bach
# 2  data/raw/midiclassics/Bach/Bwv001- 400 Chorale...     bach
# 3  data/raw/midiclassics/Bach/Bwv ''Little Notebo...     bach
# 4  data/raw/midiclassics/Bach/Bwv1066-1069 Orches...     bach
#
#                                    filename
# 0  Bwv1043 Two Violins Concerto n3 2mov.mid
# 1                               bach_4p.mid
# 2                              033600b_.mid
# 3                             02 Menuet.mid
# 4      Bwv1067 Orchestral Suite n2 2mov.mid

# %% [markdown]
# ## 3. Preprocessing Stage 1 — Tokenization

# %%
# ---------------------------------------------------------------------------
# 3.1 MIDI -> symbolic token sequence (music21)
# ---------------------------------------------------------------------------
def tokenize_midi(filepath):
    """Tokenize a MIDI file into an ordered list of note/chord string tokens.

    Returns None if the file cannot be parsed (corrupted / malformed MIDI) —
    these are logged separately rather than silently dropped, for an honest
    accounting of data quality.
    """
    try:
        score = music21.converter.parse(filepath)
    except Exception:
        return None

    try:
        parts = music21.instrument.partitionByInstrument(score)
        elements = parts.parts[0].recurse() if parts and parts.parts else score.flat.notes
    except Exception:
        elements = score.flat.notes

    tokens = []
    for el in elements:
        if isinstance(el, music21.note.Note):
            tokens.append(str(el.pitch))
        elif isinstance(el, music21.chord.Chord):
            tokens.append('.'.join(str(p) for p in el.normalOrder))

    return tokens if tokens else None


tokenized_corpus = []
failed_files = []

for _, row in file_manifest.iterrows():
    toks = tokenize_midi(row["filepath"])
    if toks is None:
        failed_files.append(row["filepath"])
    else:
        tokenized_corpus.append({
            "filepath": row["filepath"],
            "composer": row["composer"],
            "tokens": toks,
        })

print(f"Tokenized {len(tokenized_corpus)} files successfully.")
print(f"Failed to parse {len(failed_files)} files.")

tokens_df = pd.DataFrame(tokenized_corpus)
tokens_df["n_tokens"] = tokens_df["tokens"].apply(len)
tokens_df[["composer", "n_tokens"]].groupby("composer").describe()
# Out:
# Tokenized 211 files successfully.
# Failed to parse 109 files.
#          n_tokens                                                          \
#             count         mean          std   min    25%     50%      75%
# composer
# bach         70.0   797.014286   885.766916  63.0  264.0   435.5  1002.00
# beeth        42.0  3342.928571  3831.885223  32.0  706.5  1481.0  5189.00
# chopin       43.0   949.767442   724.463967  80.0  482.5   720.0  1133.00
# mozart       56.0  2026.625000  2545.312887  66.0  421.5   744.0  2210.75
#
#
#               max
# composer
# bach       5471.0
# beeth     17902.0
# chopin     3469.0
# mozart     9783.0

# %%
# ---------------------------------------------------------------------------
# 3.1.1 Illustrate tokenization on one example file
# ---------------------------------------------------------------------------
example = tokens_df.iloc[0]
print(f"File: {example['filepath']}  (composer: {example['composer']})")
print(f"First 25 tokens:\n{example['tokens'][:25]}")
# Out:
# File: data/raw/midiclassics/Varios - Ti'tulo desconocido/a_h/bach_4p.mid  (composer: bach)
# First 25 tokens:
# ['D4', 'E4', 'F4', 'G4', 'A4', 'B-4', 'C#4', 'B-4', 'A4', 'G4', 'F4', 'E4', 'F4', 'D3', 'E3', 'A4', 'F3', 'G3', 'D5', 'A3', 'B-3', 'G4', 'C#3', 'B-3', 'C#5']

# %%
# ---------------------------------------------------------------------------
# 3.2 Literal NLP tokenization on genuine text metadata (track/instrument names)
# ---------------------------------------------------------------------------
def extract_metadata_text(filepath):
    """Pull track/instrument names out of a MIDI file as free text, for a
    literal (non-analogical) demonstration of NLP tokenization."""
    try:
        pm = pretty_midi.PrettyMIDI(filepath)
    except Exception:
        return ""
    names = [instr.name for instr in pm.instruments if instr.name]
    return " ".join(names)

sample_paths = tokens_df["filepath"].sample(min(30, len(tokens_df)), random_state=SEED)
metadata_texts = [extract_metadata_text(p) for p in sample_paths]
metadata_texts = [t for t in metadata_texts if t.strip()]

print(f"Recovered non-empty text metadata from {len(metadata_texts)} sample files.\n")
if metadata_texts:
    print("Example raw metadata string:", repr(metadata_texts[0]))
    print("\nnltk.word_tokenize output:", word_tokenize(metadata_texts[0]))
else:
    print("No textual track metadata present in this sample; "
          "this is common for MIDI files exported without instrument labels. "
          "The literal-NLP demonstration is illustrative and does not gate "
          "the rest of the pipeline, which relies on the symbolic tokens.")
# Out:
# Recovered non-empty text metadata from 20 sample files.
#
# Example raw metadata string: 'Instrument 1 Instrument 2 Instrument 3 Instrument 4'
#
# nltk.word_tokenize output: ['Instrument', '1', 'Instrument', '2', 'Instrument', '3', 'Instrument', '4']

# %% [markdown]
# ## 4. Preprocessing Stage 2 — Lowercasing

# %%
# ---------------------------------------------------------------------------
# 4.1 Literal case-folding
# ---------------------------------------------------------------------------
def lowercase_tokens(tokens):
    return [t.lower() for t in tokens]

tokens_df["tokens_lower"] = tokens_df["tokens"].apply(lowercase_tokens)

# ---------------------------------------------------------------------------
# 4.2 Quantify enharmonic-spelling collapse (the musically meaningful analogue)
# ---------------------------------------------------------------------------
def pitch_class_of(token):
    """Map a note or chord token to its underlying pitch-class set, to
    measure how much surface-level 'spelling' variation exists."""
    try:
        if '.' in token:
            return token  # chord tokens are already pitch-class integers
        p = music21.pitch.Pitch(token)
        return str(p.pitchClass)
    except Exception:
        return token

vocab_before = {t for seq in tokens_df["tokens"] for t in seq}
vocab_after_case = {t for seq in tokens_df["tokens_lower"] for t in seq}
vocab_after_enharmonic = {pitch_class_of(t) for seq in tokens_df["tokens"] for t in seq}

print(f"Vocabulary size, raw tokens:                {len(vocab_before)}")
print(f"Vocabulary size, after case-folding:        {len(vocab_after_case)}  "
      f"(reduction: {len(vocab_before) - len(vocab_after_case)})")
print(f"Vocabulary size, after enharmonic collapse:  {len(vocab_after_enharmonic)}  "
      f"(reduction: {len(vocab_before) - len(vocab_after_enharmonic)})")
# Out:
# Vocabulary size, raw tokens:                753
# Vocabulary size, after case-folding:        753  (reduction: 0)
# Vocabulary size, after enharmonic collapse:  668  (reduction: 85)

# %% [markdown]
# ## 5. Preprocessing Stage 3 — Stopword Removal

# %%
# ---------------------------------------------------------------------------
# 5.1 Literal NLP stopwords (reference only)
# ---------------------------------------------------------------------------
english_stopwords = set(nltk_stopwords.words("english"))
print(f"nltk English stopword list size: {len(english_stopwords)}")
print("Sample:", sorted(list(english_stopwords))[:15])
# Out:
# nltk English stopword list size: 198
# Sample: ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't"]

# %%
# ---------------------------------------------------------------------------
# 5.2 Data-driven document-frequency stopword removal for music tokens
# ---------------------------------------------------------------------------
N_DOCS = len(tokens_df)

doc_freq = Counter()
for seq in tokens_df["tokens_lower"]:
    doc_freq.update(set(seq))  # count each token once per document

doc_freq_df = (
    pd.DataFrame(doc_freq.items(), columns=["token", "doc_count"])
    .assign(doc_freq=lambda d: d["doc_count"] / N_DOCS)
    .sort_values("doc_freq", ascending=False)
)

DF_THRESHOLD = 0.90  # token appears in >90% of all pieces -> low discriminative power
musical_stopwords = set(doc_freq_df.loc[doc_freq_df["doc_freq"] > DF_THRESHOLD, "token"])

print(f"Tokens exceeding DF > {DF_THRESHOLD:.0%}: {len(musical_stopwords)}")
doc_freq_df.head(15)
# Out:
# Tokens exceeding DF > 90%: 2
#    token  doc_count  doc_freq
# 11    d5        194  0.919431
# 28    a4        192  0.909953
# 41    g4        183  0.867299
# 4     b4        181  0.857820
# 10    e5        180  0.853081
# 8     d4        177  0.838863
# 18    c5        174  0.824645
# 39    e4        174  0.824645
# 37   f#4        169  0.800948
# 0     f4        166  0.786730
# 22   c#5        162  0.767773
# 40    c4        160  0.758294
# 1     a3        159  0.753555
# 36    g5        157  0.744076
# 32   g#4        157  0.744076

# %%
# ---------------------------------------------------------------------------
# 5.3 Apply musical-stopword removal
# ---------------------------------------------------------------------------
def remove_stopwords(tokens, stopword_set):
    return [t for t in tokens if t not in stopword_set]

tokens_df["tokens_nostop"] = tokens_df["tokens_lower"].apply(
    lambda seq: remove_stopwords(seq, musical_stopwords)
)

before_avg_len = tokens_df["tokens_lower"].apply(len).mean()
after_avg_len = tokens_df["tokens_nostop"].apply(len).mean()

print(f"Average sequence length before stopword removal: {before_avg_len:.1f}")
print(f"Average sequence length after stopword removal:  {after_avg_len:.1f}")
print(f"Average tokens removed per document:              {before_avg_len - after_avg_len:.1f}")
# Out:
# Average sequence length before stopword removal: 1661.3
# Average sequence length after stopword removal:  1560.2
# Average tokens removed per document:              101.1

# %% [markdown]
# ## 6. Preprocessing Stage 4 — Stemming vs. Lemmatization

# %%
# ---------------------------------------------------------------------------
# 6.1 MusicStemmer — rule-based, aggressive octave-folding
# ---------------------------------------------------------------------------
def music_stem(token):
    """Rule-based reduction: strip the octave digit from a note token, or
    reduce a chord token to its sorted, deduplicated pitch-class set.
    Purely syntactic — no music-theoretic lookup, analogous to Porter
    stemming's mechanical suffix stripping."""
    if '.' in token:
        pcs = sorted(set(int(p) for p in token.split('.')))
        return '.'.join(str(p) for p in pcs)
    return re.sub(r'\d+$', '', token)  # e.g. "C#4" -> "C#"


# ---------------------------------------------------------------------------
# 6.2 MusicLemmatizer — knowledge-based, music21 prime-form canonicalization
# ---------------------------------------------------------------------------
def music_lemmatize(token):
    """Knowledge-based reduction using music-theoretic set-class identity.
    Chords are mapped to their prime form (transposition/inversion
    invariant canonical form); notes are mapped to pitch class. Falls back
    to the raw token if music21 cannot parse it."""
    try:
        if '.' in token:
            pcs = [int(p) for p in token.split('.')]
            c = music21.chord.Chord(pcs)
            return '.'.join(str(p) for p in c.primeForm)
        else:
            p = music21.pitch.Pitch(token)
            return str(p.pitchClass)
    except Exception:
        return token


tokens_df["tokens_stemmed"] = tokens_df["tokens_nostop"].apply(
    lambda seq: [music_stem(t) for t in seq]
)
tokens_df["tokens_lemmatized"] = tokens_df["tokens_nostop"].apply(
    lambda seq: [music_lemmatize(t) for t in seq]
)

vocab_nostop = {t for seq in tokens_df["tokens_nostop"] for t in seq}
vocab_stemmed = {t for seq in tokens_df["tokens_stemmed"] for t in seq}
vocab_lemmatized = {t for seq in tokens_df["tokens_lemmatized"] for t in seq}

print(f"Vocabulary size before stemming/lemmatization: {len(vocab_nostop)}")
print(f"Vocabulary size after stemming (aggressive):    {len(vocab_stemmed)}")
print(f"Vocabulary size after lemmatization (canonical): {len(vocab_lemmatized)}")
# Out:
# Vocabulary size before stemming/lemmatization: 751
# Vocabulary size after stemming (aggressive):    669
# Vocabulary size after lemmatization (canonical): 90

# %%
# ---------------------------------------------------------------------------
# 6.3 Side-by-side example: raw -> stemmed -> lemmatized
# ---------------------------------------------------------------------------
sample_tokens = tokens_df.iloc[0]["tokens_nostop"][:10]
comparison_table = pd.DataFrame({
    "raw_token": sample_tokens,
    "stemmed": [music_stem(t) for t in sample_tokens],
    "lemmatized": [music_lemmatize(t) for t in sample_tokens],
})
comparison_table
# Out:
#   raw_token stemmed lemmatized
# 0        d4       d          2
# 1        e4       e          4
# 2        f4       f          5
# 3        g4       g          7
# 4       b-4      b-         10
# 5       c#4      c#          1
# 6       b-4      b-         10
# 7        g4       g          7
# 8        f4       f          5
# 9        e4       e          4

# %% [markdown]
# ## 7. Assembling the Final Preprocessed Corpus

# %%
# ---------------------------------------------------------------------------
# 7.1 Final document corpora (list-of-tokens, ready for vectorization)
# ---------------------------------------------------------------------------
corpus_stemmed = tokens_df["tokens_stemmed"].tolist()
corpus_lemmatized = tokens_df["tokens_lemmatized"].tolist()
labels = tokens_df["composer"].tolist()

label_encoder = LabelEncoder().fit(COMPOSERS)
y = label_encoder.transform(labels)

print(f"Final corpus: {len(corpus_stemmed)} documents across {len(set(labels))} composers.")
print(f"Example (stemmed) document, first 15 tokens: {corpus_stemmed[0][:15]}")

# Persist for teammates / later sections
with open("preprocessed_corpus.pkl", "wb") as f:
    pickle.dump({
        "corpus_stemmed": corpus_stemmed,
        "corpus_lemmatized": corpus_lemmatized,
        "labels": labels,
        "filepaths": tokens_df["filepath"].tolist(),
    }, f)
print("Saved preprocessed_corpus.pkl")
# Out:
# Final corpus: 211 documents across 4 composers.
# Example (stemmed) document, first 15 tokens: ['d', 'e', 'f', 'g', 'b-', 'c#', 'b-', 'g', 'f', 'e', 'f', 'd', 'e', 'f', 'g']
# Saved preprocessed_corpus.pkl

# %% [markdown]
# ## 8. Vectorization Method 1 — Bag-of-Words (`CountVectorizer`)

# %%
# ---------------------------------------------------------------------------
# 8.1 Fit CountVectorizer on the lemmatized corpus (chosen as primary; the
#     stemmed corpus is fit identically for the ablation in Section 12-13)
# ---------------------------------------------------------------------------
t0 = time.time()
bow_vectorizer = CountVectorizer(analyzer=lambda tokens: tokens, min_df=2)
X_bow = bow_vectorizer.fit_transform(corpus_lemmatized)
bow_fit_time = time.time() - t0

print(f"Bag-of-Words matrix shape: {X_bow.shape}")
print(f"Vocabulary size (min_df=2): {len(bow_vectorizer.vocabulary_)}")
print(f"Sparsity: {(1 - X_bow.nnz / (X_bow.shape[0] * X_bow.shape[1])):.4%}")
print(f"Fit time: {bow_fit_time:.2f}s")
# Out:
# Bag-of-Words matrix shape: (211, 71)
# Vocabulary size (min_df=2): 71
# Sparsity: 72.1647%
# Fit time: 0.02s

# %%
# ---------------------------------------------------------------------------
# 8.2 Most frequent tokens overall, and per composer
# ---------------------------------------------------------------------------
vocab_terms = np.array(bow_vectorizer.get_feature_names_out())
total_counts = np.asarray(X_bow.sum(axis=0)).ravel()
top_overall = vocab_terms[np.argsort(total_counts)[::-1][:15]]
print("Top 15 most frequent tokens overall:", list(top_overall))

for composer in COMPOSERS:
    mask = np.array(labels) == composer
    composer_counts = np.asarray(X_bow[mask].sum(axis=0)).ravel()
    top_composer = vocab_terms[np.argsort(composer_counts)[::-1][:10]]
    print(f"\nTop 10 tokens for {composer}: {list(top_composer)}")
# Out:
# Top 15 most frequent tokens overall: ['7', '0', '4', '2', '5', '9', '11', '10', '3', '6', '0.3', '1', '8', '0.4', '0.2']
#
# Top 10 tokens for bach: ['7', '0', '4', '2', '5', '11', '9', '10', '3', '6']
#
# Top 10 tokens for beeth: ['7', '0', '5', '10', '2', '11', '4', '3', '9', '6']
#
# Top 10 tokens for chopin: ['0.3', '0.3.7', '8', '1', '3', '0', '0.4', '0.5', '10', '11']
#
# Top 10 tokens for mozart: ['7', '4', '9', '0', '2', '11', '5', '6', '0.3', '10']

# %% [markdown]
# ## 9. Vectorization Method 2 — TF-IDF (`TfidfVectorizer`)

# %%
# ---------------------------------------------------------------------------
# 9.1 Fit TfidfVectorizer (same tokenization contract as CountVectorizer)
# ---------------------------------------------------------------------------
t0 = time.time()
tfidf_vectorizer = TfidfVectorizer(analyzer=lambda tokens: tokens, min_df=2)
X_tfidf = tfidf_vectorizer.fit_transform(corpus_lemmatized)
tfidf_fit_time = time.time() - t0

print(f"TF-IDF matrix shape: {X_tfidf.shape}")
print(f"Sparsity: {(1 - X_tfidf.nnz / (X_tfidf.shape[0] * X_tfidf.shape[1])):.4%}")
print(f"Fit time: {tfidf_fit_time:.2f}s")
# Out:
# TF-IDF matrix shape: (211, 71)
# Sparsity: 72.1647%
# Fit time: 0.02s

# %%
# ---------------------------------------------------------------------------
# 9.2 Most distinctive (highest mean TF-IDF) tokens per composer
# ---------------------------------------------------------------------------
tfidf_terms = np.array(tfidf_vectorizer.get_feature_names_out())

for composer in COMPOSERS:
    mask = np.array(labels) == composer
    mean_tfidf = np.asarray(X_tfidf[mask].mean(axis=0)).ravel()
    top_terms = tfidf_terms[np.argsort(mean_tfidf)[::-1][:10]]
    print(f"Most distinctive tokens for {composer} (by mean TF-IDF): {list(top_terms)}")
# Out:
# Most distinctive tokens for bach (by mean TF-IDF): ['4', '7', '0', '2', '11', '5', '9', '6', '10', '1']
# Most distinctive tokens for beeth (by mean TF-IDF): ['7', '0', '2', '0.3', '5', '10', '11', '4', '9', '0.4']
# Most distinctive tokens for chopin (by mean TF-IDF): ['0.3.7', '0.3', '3', '8', '0.4', '0.5', '1', '0', '10', '11']
# Most distinctive tokens for mozart (by mean TF-IDF): ['7', '0', '9', '4', '2', '0.3', '5', '11', '10', '6']

# %% [markdown]
# ## 10. Vectorization Method 3 — Word2Vec (CBOW and Skip-gram)

# %%
# ---------------------------------------------------------------------------
# 10.1 Train CBOW (sg=0) and Skip-gram (sg=1)
# ---------------------------------------------------------------------------
W2V_PARAMS = dict(vector_size=100, window=5, min_count=2, workers=4, epochs=20, seed=SEED)

t0 = time.time()
w2v_cbow = Word2Vec(sentences=corpus_lemmatized, sg=0, **W2V_PARAMS)
cbow_train_time = time.time() - t0

t0 = time.time()
w2v_skipgram = Word2Vec(sentences=corpus_lemmatized, sg=1, **W2V_PARAMS)
skipgram_train_time = time.time() - t0

print(f"CBOW vocabulary size:     {len(w2v_cbow.wv.key_to_index)}   (train time: {cbow_train_time:.2f}s)")
print(f"Skip-gram vocabulary size: {len(w2v_skipgram.wv.key_to_index)}   (train time: {skipgram_train_time:.2f}s)")
# Out:
# CBOW vocabulary size:     78   (train time: 0.45s)
# Skip-gram vocabulary size: 78   (train time: 0.86s)

# %%
# ---------------------------------------------------------------------------
# 10.2 Intrinsic evaluation: nearest neighbors for a frequent, musically
#      interpretable token (e.g. a common major-triad prime form "0.4.7")
# ---------------------------------------------------------------------------
probe_token = vocab_terms[np.argsort(total_counts)[::-1][0]]  # most frequent lemmatized token
print(f"Probe token (most frequent overall): {probe_token}\n")

if probe_token in w2v_cbow.wv:
    print("CBOW nearest neighbors:")
    for tok, sim in w2v_cbow.wv.most_similar(probe_token, topn=8):
        print(f"  {tok:12s}  cosine similarity = {sim:.3f}")

if probe_token in w2v_skipgram.wv:
    print("\nSkip-gram nearest neighbors:")
    for tok, sim in w2v_skipgram.wv.most_similar(probe_token, topn=8):
        print(f"  {tok:12s}  cosine similarity = {sim:.3f}")
# Out:
# Probe token (most frequent overall): 7
#
# CBOW nearest neighbors:
#   0             cosine similarity = 0.685
#   2             cosine similarity = 0.576
#   11            cosine similarity = 0.344
#   5             cosine similarity = 0.305
#   4             cosine similarity = 0.251
#   10            cosine similarity = 0.203
#   0.1.5.7       cosine similarity = 0.202
#   3             cosine similarity = 0.197
#
# Skip-gram nearest neighbors:
#   0             cosine similarity = 0.894
#   2             cosine similarity = 0.855
#   11            cosine similarity = 0.782
#   4             cosine similarity = 0.779
#   5             cosine similarity = 0.777
#   9             cosine similarity = 0.767
#   6             cosine similarity = 0.743
#   10            cosine similarity = 0.729

# %%
# ---------------------------------------------------------------------------
# 10.3 Document-level Word2Vec features (mean-pooled token embeddings)
# ---------------------------------------------------------------------------
def document_vector(tokens, w2v_model):
    """Average the embeddings of all in-vocabulary tokens in a document.
    Documents with no in-vocabulary tokens fall back to a zero vector."""
    vectors = [w2v_model.wv[t] for t in tokens if t in w2v_model.wv]
    if not vectors:
        return np.zeros(w2v_model.vector_size)
    return np.mean(vectors, axis=0)

X_w2v_cbow = np.vstack([document_vector(doc, w2v_cbow) for doc in corpus_lemmatized])
X_w2v_skipgram = np.vstack([document_vector(doc, w2v_skipgram) for doc in corpus_lemmatized])

print("Document-level CBOW feature matrix:     ", X_w2v_cbow.shape)
print("Document-level Skip-gram feature matrix:", X_w2v_skipgram.shape)
# Out:
# Document-level CBOW feature matrix:      (211, 100)
# Document-level Skip-gram feature matrix: (211, 100)

# %% [markdown]
# ## 11. Embedding Visualization

# %%
# ---------------------------------------------------------------------------
# 11.1 PCA and t-SNE projections of the CBOW token embedding space
# ---------------------------------------------------------------------------
top_n_tokens = 300  # visualize the most frequent tokens only, for legibility
frequent_tokens = vocab_terms[np.argsort(total_counts)[::-1][:top_n_tokens]]
frequent_tokens = [t for t in frequent_tokens if t in w2v_cbow.wv]

embedding_matrix = np.vstack([w2v_cbow.wv[t] for t in frequent_tokens])

pca_2d = PCA(n_components=2, random_state=SEED).fit_transform(embedding_matrix)
tsne_2d = TSNE(n_components=2, random_state=SEED, perplexity=30).fit_transform(embedding_matrix)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].scatter(pca_2d[:, 0], pca_2d[:, 1], s=10, alpha=0.6)
axes[0].set_title("PCA — CBOW Token Embeddings")

axes[1].scatter(tsne_2d[:, 0], tsne_2d[:, 1], s=10, alpha=0.6)
axes[1].set_title("t-SNE — CBOW Token Embeddings")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 12. Comparative Analysis of Vectorization Methods

# %%
# ---------------------------------------------------------------------------
# 12.1 Structural comparison table
# ---------------------------------------------------------------------------
def sparsity(matrix):
    if hasattr(matrix, "nnz"):
        return 1 - matrix.nnz / (matrix.shape[0] * matrix.shape[1])
    return float(np.mean(matrix == 0))

structural_comparison = pd.DataFrame([
    {"method": "Bag-of-Words", "dimensionality": X_bow.shape[1],
     "sparsity": sparsity(X_bow), "fit_time_s": bow_fit_time, "representation": "sparse, count-based"},
    {"method": "TF-IDF", "dimensionality": X_tfidf.shape[1],
     "sparsity": sparsity(X_tfidf), "fit_time_s": tfidf_fit_time, "representation": "sparse, weighted-count"},
    {"method": "Word2Vec (CBOW)", "dimensionality": X_w2v_cbow.shape[1],
     "sparsity": sparsity(X_w2v_cbow), "fit_time_s": cbow_train_time, "representation": "dense, learned embedding"},
    {"method": "Word2Vec (Skip-gram)", "dimensionality": X_w2v_skipgram.shape[1],
     "sparsity": sparsity(X_w2v_skipgram), "fit_time_s": skipgram_train_time, "representation": "dense, learned embedding"},
]).set_index("method")

structural_comparison
# Out:
#                       dimensionality  sparsity  fit_time_s  \
# method
# Bag-of-Words                      71  0.721647    0.021214
# TF-IDF                            71  0.721647    0.020799
# Word2Vec (CBOW)                  100  0.000000    0.446347
# Word2Vec (Skip-gram)             100  0.000000    0.858828
#
#                                 representation
# method
# Bag-of-Words               sparse, count-based
# TF-IDF                  sparse, weighted-count
# Word2Vec (CBOW)       dense, learned embedding
# Word2Vec (Skip-gram)  dense, learned embedding

# %% [markdown]
# ## 13. Extrinsic Evaluation (Downstream Classification Probe)

# %%
# 13.1 Cross-validated probe classifier for each representation
# ---------------------------------------------------------------------------
def cv_probe(X, y, name, n_splits=5):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)
    clf = LogisticRegression(max_iter=2000)   # multinomial is the default now
    scores = cross_val_score(clf, X, y, cv=skf, scoring="accuracy")
    print(f"{name:22s}  mean accuracy = {scores.mean():.4f}  (+/- {scores.std():.4f})")
    return scores.mean(), scores.std()

results = {}
results["Bag-of-Words"] = cv_probe(X_bow, y, "Bag-of-Words")
results["TF-IDF"] = cv_probe(X_tfidf, y, "TF-IDF")
results["Word2Vec (CBOW)"] = cv_probe(X_w2v_cbow, y, "Word2Vec (CBOW)")
results["Word2Vec (Skip-gram)"] = cv_probe(X_w2v_skipgram, y, "Word2Vec (Skip-gram)")
# Out:
# Bag-of-Words            mean accuracy = 0.7202  (+/- 0.0472)
# TF-IDF                  mean accuracy = 0.5639  (+/- 0.0204)
# Word2Vec (CBOW)         mean accuracy = 0.5544  (+/- 0.0202)
# Word2Vec (Skip-gram)    mean accuracy = 0.5168  (+/- 0.0379)

# %%
# ---------------------------------------------------------------------------
# 13.2 Stemmed- vs. lemmatized-corpus ablation (using Bag-of-Words as the probe)
# ---------------------------------------------------------------------------
bow_stemmed_vectorizer = CountVectorizer(analyzer=lambda tokens: tokens, min_df=2)
X_bow_stemmed = bow_stemmed_vectorizer.fit_transform(corpus_stemmed)

print("Ablation: stemmed vs. lemmatized corpus (Bag-of-Words features)")
cv_probe(X_bow_stemmed, y, "BoW (stemmed corpus)")
cv_probe(X_bow, y, "BoW (lemmatized corpus)")
# Out:
# Ablation: stemmed vs. lemmatized corpus (Bag-of-Words features)
# BoW (stemmed corpus)    mean accuracy = 0.5640  (+/- 0.0234)
# BoW (lemmatized corpus)  mean accuracy = 0.7202  (+/- 0.0472)
# (np.float64(0.7201550387596899), np.float64(0.047237130286007276))

# %%
# ---------------------------------------------------------------------------
# 13.3 Visual summary of the extrinsic evaluation
# ---------------------------------------------------------------------------
summary_df = pd.DataFrame(
    [(k, v[0], v[1]) for k, v in results.items()],
    columns=["method", "mean_accuracy", "std_accuracy"]
).sort_values("mean_accuracy", ascending=False)

plt.figure(figsize=(7, 4))
sns.barplot(data=summary_df, x="method", y="mean_accuracy", palette="viridis")
plt.errorbar(x=range(len(summary_df)), y=summary_df["mean_accuracy"],
             yerr=summary_df["std_accuracy"], fmt="none", c="black", capsize=4)
plt.ylabel("5-fold CV Accuracy (Logistic Regression probe)")
plt.title("Extrinsic Comparison of Vectorization Methods")
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

summary_df
# Out:
#                  method  mean_accuracy  std_accuracy
# 0          Bag-of-Words       0.720155      0.047237
# 1                TF-IDF       0.563898      0.020413
# 2       Word2Vec (CBOW)       0.554374      0.020231
# 3  Word2Vec (Skip-gram)       0.516833      0.037868

# %% [markdown]
# ## 14. Handoff Artifacts for the Team

# %%
import os
import numpy as np
import scipy.sparse as sp
import dill  # Instantly resolves lambda pickling issues

# ---------------------------------------------------------------------------
# 14.1 Persist all pipeline artifacts safely
# ---------------------------------------------------------------------------

# 1. Save scikit-learn vectorizers using dill (handles lambda functions)
with open("bow_vectorizer.pkl", "wb") as f:
    dill.dump(bow_vectorizer, f)

with open("tfidf_vectorizer.pkl", "wb") as f:
    dill.dump(tfidf_vectorizer, f)

# 2. Save Gensim Word2Vec models
w2v_cbow.save("w2v_cbow.model")
w2v_skipgram.save("w2v_skipgram.model")

# 3. Save sparse matrices efficiently without blowing up RAM
sp.save_npz("X_bow.npz", X_bow)
sp.save_npz("X_tfidf.npz", X_tfidf)

# 4. Save dense embeddings, targets, and metadata
np.savez(
    "vectorized_dense_features.npz",
    X_w2v_cbow=X_w2v_cbow,
    X_w2v_skipgram=X_w2v_skipgram,
    y=y,
    composer_classes=label_encoder.classes_,
)

print("All handoff artifacts saved successfully!")
print("Saved files:", os.listdir("."))
# Out:
# All handoff artifacts saved successfully!
# Saved files: ['tfidf_vectorizer.pkl', 'bow_vectorizer.pkl', 'w2v_cbow.model', '02_feature_extraction.ipynb', 'X_tfidf.npz', 'w2v_skipgram.model', 'file_manifest.csv', '03_model_building_and_evaluation.ipynb', '01_data_preprocessing.ipynb', 'data', 'X_bow.npz', 'vectorized_dense_features.npz', 'preprocessed_corpus.pkl']

# %% [markdown]
# ## 15. References
#
# Blanderbuss. (n.d.). *Classical music MIDI* [Data set]. Kaggle.
# https://www.kaggle.com/datasets/blanderbuss/midi-classic-music
#
# Chuan, C.-H., Agres, K., & Herremans, D. (2020). From context to concept:
# Exploring semantic relationships in music with word2vec. *Neural Computing
# and Applications, 32*, 1023–1036.
#
# Cuthbert, M. S., & Ariza, C. (2010). music21: A toolkit for computer-aided
# musicology and symbolic music data. In *Proceedings of the 11th
# International Society for Music Information Retrieval Conference*
# (pp. 637–642).
#
# Forte, A. (1973). *The structure of atonal music*. Yale University Press.
#
# Herremans, D., Chuan, C.-H., & Chew, E. (2017). A functional taxonomy of
# music generation systems. *ACM Computing Surveys, 50*(5), 1–30.
#
# Huang, C.-Z. A., Vaswani, A., Uszkoreit, J., Shazeer, N., Simon, I.,
# Hawthorne, C., Dai, A. M., Hoffman, M. D., Dinculescu, M., & Eck, D.
# (2019). Music Transformer: Generating music with long-term structure. In
# *Proceedings of the International Conference on Learning
# Representations*.
#
# Manning, C. D., Raghavan, P., & Schütze, H. (2008). *Introduction to
# information retrieval*. Cambridge University Press.
#
# Mikolov, T., Chen, K., Corrado, G., & Dean, J. (2013a). Efficient
# estimation of word representations in vector space. *arXiv preprint
# arXiv:1301.3781*.
#
# Mikolov, T., Sutskever, I., Chen, K., Corrado, G., & Dean, J. (2013b).
# Distributed representations of words and phrases and their
# compositionality. *Advances in Neural Information Processing Systems, 26*,
# 3111–3119.
#
# Miller, G. A. (1995). WordNet: A lexical database for English.
# *Communications of the ACM, 38*(11), 39–41.
#
# Oore, S., Simon, I., Dieleman, S., Eck, D., & Simoncelli, E. (2020). This
# time with feeling: Learning expressive musical performance. *Neural
# Computing and Applications, 32*, 955–967.
#
# Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B.,
# Grisel, O., et al. (2011). Scikit-learn: Machine learning in Python.
# *Journal of Machine Learning Research, 12*, 2825–2830.
#
# Porter, M. F. (1980). An algorithm for suffix stripping. *Program, 14*(3),
# 130–137.
#
# Raffel, C., & Ellis, D. P. W. (2014). Intuitive analysis, creation and
# manipulation of MIDI data with pretty_midi. In *Proceedings of the 15th
# International Society for Music Information Retrieval Conference, Late
# Breaking and Demo Papers* (pp. 84–93).
#
# Řehůřek, R., & Sojka, P. (2010). Software framework for topic modelling
# with large corpora. In *Proceedings of the LREC 2010 Workshop on New
# Challenges for NLP Frameworks* (pp. 45–50). [gensim]
#
# Salton, G., & Buckley, C. (1988). Term-weighting approaches in automatic
# text retrieval. *Information Processing & Management, 24*(5), 513–523.
#
# van der Maaten, L., & Hinton, G. (2008). Visualizing data using t-SNE.
# *Journal of Machine Learning Research, 9*, 2579–2605.
